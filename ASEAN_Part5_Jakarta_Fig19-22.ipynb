# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaitokidbua/ASEAN_Transport/blob/main/ASEAN_Part5_Jakarta_Fig19-22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ── Setup ────────────────────────────────────────────────────────────────────
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')

# ── Dark Theme ────────────────────────────────────────────────────────────────
PAPER_BG   = '#0D1117'
PLOT_BG    = '#161B22'
GRID_C     = '#30363D'
FONT_C     = '#E6EDF3'
MUTED_C    = '#8B949E'
TEMPLATE   = 'plotly_dark'

CITY_COLORS = {
    'Bangkok':      '#FF6B6B',
    'Singapore':    '#74B9FF',
    'Kuala Lumpur': '#4ECDC4',
    'Jakarta':      '#FFB347',
    'Manila':       '#C77DFF',
}

def base_layout(height=460, legend_h=True):
    leg = dict(bgcolor='rgba(22,27,34,0.9)', bordercolor=GRID_C, borderwidth=1, font_size=11)
    if legend_h:
        leg.update(orientation='h', y=1.13, x=1, xanchor='right')
    return dict(
        template=TEMPLATE, paper_bgcolor=PAPER_BG, plot_bgcolor=PLOT_BG,
        font=dict(color=FONT_C, family='Segoe UI, Arial, sans-serif'),
        height=height, legend=leg,
        margin=dict(l=60, r=40, t=75, b=55),
        hoverlabel=dict(bgcolor='#1F2937', bordercolor=GRID_C, font_size=12),
    )

def ax_style():
    return dict(gridcolor=GRID_C, zerolinecolor=GRID_C)

print('✅ Setup complete — Dark theme loaded')
# Out:
# ✅ Setup complete — Dark theme loaded

# %%
# ── Load Data ─────────────────────────────────────────────────────────────────
df = pd.read_csv('ASEAN_Urban_Growth_Final_with_Mode.csv')
df['Date']  = pd.to_datetime(df['Date'])
df['Year']  = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# ── Mode label maps ───────────────────────────────────────────────────────────
MODE_BKK = {'BTS':'BTS Skytrain','MRT':'MRT Blue/Purple','SRT':'SRT Red Line',
             'ARL':'Airport Rail Link','YL':'MRT Yellow Line','PK':'MRT Pink Line','RL':'Regional Rail'}
MODE_SGP = {'MRT':'MRT','Public Bus':'Public Bus','LRT':'LRT'}
MODE_KL  = {
    'rail_lrt_kj':'LRT Kelana Jaya','rail_mrt_kajang':'MRT Kajang',
    'rail_lrt_ampang':'LRT Ampang','bus_rkl':'RapidKL Bus',
    'rail_mrt_pjy':'MRT Putrajaya','rail_monorail':'KL Monorail',
    'rail_komuter':'KTM Komuter','rail_komuter_utara':'KTM Utara',
    'rail_ets':'ETS Train','rail_intercity':'Intercity Rail',
    'rail_tebrau':'KTM Tebrau','bus_rkn':'RapidKN Bus','bus_rpn':'RapidPN Bus'
}
MODE_JKT = {'TRANSJAKARTA':'TransJakarta (BRT)','KRL':'KRL Commuter',
             'MRT':'MRT Jakarta','LRT':'LRT Jakarta',
             'BUS SEKOLAH':'School Bus','KCI COMMUTER BANDARA':'Airport Rail','KAPAL':'Ferry'}

print(f'Dataset: {df.shape[0]:,} rows | {df["City"].nunique()} cities')
print('Cities:', df['City'].unique().tolist())
# Out:
# Dataset: 2,027 rows | 5 cities
# Cities: ['Bangkok', 'Jakarta', 'Kuala Lumpur', 'Singapore', 'Manila']

# %%
# ── Jakarta: prep data ────────────────────────────────────────────────────────
jkt = df[(df['City']=='Jakarta') & (df['Year'].isin([2024,2025]))].copy()
jkt['Mode_Label'] = jkt['Mode'].map(lambda x: MODE_JKT.get(x,x))

jkt_m  = jkt.groupby('Date')['Ridership'].sum().reset_index()
jkt_yr = jkt.groupby(['Year','Mode_Label'])['Ridership'].sum().reset_index()
jkt_sh = jkt.groupby('Mode_Label')['Ridership'].sum().reset_index().sort_values('Ridership',ascending=False)

yoy_list=[]
for mode in jkt['Mode_Label'].unique():
    sub = jkt_yr[jkt_yr['Mode_Label']==mode].sort_values('Year').copy()
    sub['YoY'] = sub['Ridership'].pct_change()*100
    yoy_list.append(sub)
jkt_yoy = pd.concat(yoy_list).dropna(subset=['YoY'])
JKT_CLR = ['#FFB347','#FF6B6B','#74B9FF','#4ECDC4','#C77DFF','#A8E6CF','#FD79A8']
print('Jakarta data ready ✅')
# Out:
# Jakarta data ready ✅

# %%
# 4.1 Monthly
fig = px.area(jkt_m, x='Date', y='Ridership',
    title='<b>Fig.19</b>  จาการ์ตา — ผู้โดยสารรายเดือน (2024–2025)',
    labels={'Ridership':'จำนวนผู้โดยสาร','Date':''},
    color_discrete_sequence=[CITY_COLORS['Jakarta']])
fig.update_traces(fillcolor='rgba(255,179,71,0.13)', line_color=CITY_COLORS['Jakarta'], line_width=2.2)
fig.update_layout(**base_layout(420), hovermode='x unified',
                  yaxis=dict(tickformat='.2s',**ax_style()), xaxis=ax_style())

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="42d9b905-7ff8-4761-aa04-c3ecd58cf759" class="plotly-graph-div" style="height:420px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42d9b905-7ff8-4761-aa04-c3ecd58cf759")) {                    Plotly.newPlot(                        "42d9b905-7ff8-4761-aa04-c3ecd58cf759",                        [{"fillpattern":{"shape":""},"hovertemplate":"=%{x}\u003cbr\u003eจำนวนผู้โดยสาร=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#FFB347","width":2.2},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","x":["2024-01-01T00:00:00","2024-02-01T00:00:00","2024-03-01T00:00:00","2024-04-01T00:00:00","2024-05-01T00:00:00","2024-06-01T00:00:00","2024-07-01T00:00:00","2024-08-01T00:00:00","2024-09-01T00:00:00","2024-10-01T00:00:00","2024-11-01T00:00:00","2024-12-01T00:00:00","2025-01-01T00:00:00","2025-02-01T00:00:00","2025-03-01T00:00:00","2025-04-01T00:00:00","2025-05-01T00:00:00","2025-06-01T00:00:00","2025-07-01T00:00:00","2025-08-01T00:00:00","2025-09-01T00:00:00","2025-10-01T00:00:00","2025-11-01T00:00:00","2025-12-01T00:00:00"],"xaxis":"x","y":[62286524.0,57080098.0,59880977.0,55902441.0,63550890.0,62566823.0,69677569.0,66486088.0,64824228.0,70766388.0,63318153.0,63294638.0,64754212.0,63251280.0,60523126.0,61652385.0,66618299.0,65469573.0,74421933.0,69592052.0,70334520.0,77936045.0,73547167.0,90869704.0],"yaxis":"y","type":"scatter","fillcolor":"rgba(255,179,71,0.13)"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0 ...

# %%
fig = px.bar(
    jkt_sh,
    x='Ridership',
    y='Mode_Label',
    orientation='h', # Horizontal bar chart
    title='<b>Fig.20</b>  จาการ์ตา — สัดส่วนผู้โดยสารแต่ละระบบ (2024–2025)',
    labels={'Ridership':'จำนวนผู้โดยสาร','Mode_Label':'ระบบขนส่ง'},
    color='Mode_Label', # Color by mode label
    color_discrete_sequence=JKT_CLR,
)

# Get the base layout configuration
layout_config = base_layout(460, legend_h=False)
# Update the legend properties
layout_config['legend'].update(orientation='v', y=0.5, yanchor='middle', x=1.02, xanchor='left') # Adjust legend for horizontal bar chart

fig.update_layout(
    **layout_config,
    yaxis={'categoryorder': 'total ascending', 'categoryarray': jkt_sh['Ridership'].tolist()},
    xaxis=dict(tickformat='.2s', **ax_style()),
    bargap=0.1 # Adjust gap between bars
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="746c9bcb-7878-4ba0-84d1-b00d2ab942c9" class="plotly-graph-div" style="height:460px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("746c9bcb-7878-4ba0-84d1-b00d2ab942c9")) {                    Plotly.newPlot(                        "746c9bcb-7878-4ba0-84d1-b00d2ab942c9",                        [{"alignmentgroup":"True","hovertemplate":"ระบบขนส่ง=%{y}\u003cbr\u003eจำนวนผู้โดยสาร=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TransJakarta (BRT)","marker":{"color":"#FFB347","pattern":{"shape":""}},"name":"TransJakarta (BRT)","offsetgroup":"TransJakarta (BRT)","orientation":"h","showlegend":true,"textposition":"auto","x":[796294645.0],"xaxis":"x","y":["TransJakarta (BRT)"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบขนส่ง=%{y}\u003cbr\u003eจำนวนผู้โดยสาร=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"KRL Commuter","marker":{"color":"#FF6B6B","pattern":{"shape":""}},"name":"KRL Commuter","offsetgroup":"KRL Commuter","orientation":"h","showlegend":true,"textposition":"auto","x":[689979218.0],"xaxis":"x","y":["KRL Commuter"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบขนส่ง=%{y}\u003cbr\u003eจำนวนผู้โดยสาร=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MRT Jakarta","marker":{"color":"#74B9FF","pattern":{"shape":""}},"name":"MRT Jakarta","offsetgroup":"MRT Jakarta","orientation":"h","showlegend":true,"textposition":"auto","x":[85371018.0],"xaxis":"x","y":["MRT Jakarta"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบขนส่ง=%{y}\u003cbr\u003eจำนวนผู้โดยสาร=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"School Bus","marker":{"color":"#4ECDC4","pattern":{"shape":""}},"name":"School Bus","offsetgroup":"School Bus","orientation":"h","showlegend":true,"textposition":"auto","x":[17410599.0],"xaxis":"x","y":["School Bus"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบขนส่ง=%{y}\u003cbr\u003eจำนวนผู้โดยสาร=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Airport Rail","marker":{"color":"#C77DFF","pattern":{"shape":""}},"name":"Airport Rail","offsetgroup":"Airport Rail","orientation":"h","showlegend":true,"textposition":"auto","x":[4710860.0],"xaxis":"x","y":["Airport Rail"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบขนส่ง=%{y}\u003cbr\u003eจำนวนผู้โดยสาร=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LRT Jakarta","marker":{"color":"#A8E6CF","pattern":{"shape":""}},"name":"LRT Jakarta","offsetgroup":"LRT Jakarta","orientation":"h","showlegend":true,"textposition":"auto","x":[2491645.0],"xaxis":"x","y":["LRT Jakarta"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบขนส่ง=%{y}\u003cbr\u003eจำนวนผู้โดยสาร=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ferry","marker":{"color":"#FD79A8","pattern":{"shape":""}},"name":"Ferry","offsetgroup":"Ferry","orientation":"h","showlegend":true,"textposition":"auto","x":[2347128.0],"xaxis":"x","y":["Ferry"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"car ...

# %%
fig = px.bar(
    jkt_yr, x='Year', y='Ridership', color='Mode_Label',
    barmode='group', # Set to grouped bar chart as requested
    title='<b>Fig.21</b>  จาการ์ตา — ผู้โดยสารแต่ละระบบ รายปี (2024–2025)',
    labels={'Ridership':'ผู้โดยสาร','Mode_Label':'ระบบ','Year':''},
    color_discrete_sequence=JKT_CLR,
)
fig.update_layout(**base_layout(460),
                  xaxis=dict(dtick=1,**ax_style()),
                  yaxis=dict(tickformat='.2s',**ax_style()),
                  bargap=0.15) # Adjusted bargap for grouped bars
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b8d6b8fc-4530-4d95-a156-20271a825645" class="plotly-graph-div" style="height:460px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8d6b8fc-4530-4d95-a156-20271a825645")) {                    Plotly.newPlot(                        "b8d6b8fc-4530-4d95-a156-20271a825645",                        [{"alignmentgroup":"True","hovertemplate":"ระบบ=Airport Rail\u003cbr\u003e=%{x}\u003cbr\u003eผู้โดยสาร=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Airport Rail","marker":{"color":"#FFB347","pattern":{"shape":""}},"name":"Airport Rail","offsetgroup":"Airport Rail","orientation":"v","showlegend":true,"textposition":"auto","x":[2024,2025],"xaxis":"x","y":[2221248.0,2489612.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบ=Ferry\u003cbr\u003e=%{x}\u003cbr\u003eผู้โดยสาร=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ferry","marker":{"color":"#FF6B6B","pattern":{"shape":""}},"name":"Ferry","offsetgroup":"Ferry","orientation":"v","showlegend":true,"textposition":"auto","x":[2024,2025],"xaxis":"x","y":[1187696.0,1159432.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบ=KRL Commuter\u003cbr\u003e=%{x}\u003cbr\u003eผู้โดยสาร=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"KRL Commuter","marker":{"color":"#74B9FF","pattern":{"shape":""}},"name":"KRL Commuter","offsetgroup":"KRL Commuter","orientation":"v","showlegend":true,"textposition":"auto","x":[2024,2025],"xaxis":"x","y":[324245977.0,365733241.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบ=LRT Jakarta\u003cbr\u003e=%{x}\u003cbr\u003eผู้โดยสาร=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LRT Jakarta","marker":{"color":"#4ECDC4","pattern":{"shape":""}},"name":"LRT Jakarta","offsetgroup":"LRT Jakarta","orientation":"v","showlegend":true,"textposition":"auto","x":[2024,2025],"xaxis":"x","y":[1212984.0,1278661.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบ=MRT Jakarta\u003cbr\u003e=%{x}\u003cbr\u003eผู้โดยสาร=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MRT Jakarta","marker":{"color":"#C77DFF","pattern":{"shape":""}},"name":"MRT Jakarta","offsetgroup":"MRT Jakarta","orientation":"v","showlegend":true,"textposition":"auto","x":[2024,2025],"xaxis":"x","y":[40010400.0,45360618.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบ=School Bus\u003cbr\u003e=%{x}\u003cbr\u003eผู้โดยสาร=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"School Bus","marker":{"color":"#A8E6CF","pattern":{"shape":""}},"name":"School Bus","offsetgroup":"School Bus","orientation":"v","showlegend":true,"textposition":"auto","x":[2024,2025],"xaxis":"x","y":[8808034.0,8602565.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบ=TransJakarta (BRT)\u003cbr\u003e=%{x}\u003cbr\u003eผู้โดยสาร=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TransJakarta (BRT)","marker":{"color":"#FD79A8","pattern":{"shape":""}},"name":"TransJakarta (BRT)","offsetgroup":"TransJakarta (BRT)","orientation":"v","showlegend":true,"textposition":"auto","x":[2024,2025],"xaxis":"x","y":[381948478.0,414346167.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolo ...

# %%
# 4.4 YoY
fig = px.bar(jkt_yoy, x='Year', y='YoY', color='Mode_Label', barmode='group', text_auto='.1f',
    title='<b>Fig.22</b>  จาการ์ตา — อัตราการเปลี่ยนแปลงผู้โดยสาร YoY (%)',
    labels={'YoY':'YoY Change (%)','Mode_Label':'ระบบ','Year':''},
    color_discrete_sequence=JKT_CLR)
fig.add_hline(y=0, line_dash='dash', line_color=MUTED_C, line_width=1.2)
fig.update_layout(**base_layout(460),
                  xaxis=dict(dtick=1,**ax_style()),
                  yaxis=dict(ticksuffix='%',**ax_style()))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="aaac2c8b-c548-4535-bf76-8da030bd51b3" class="plotly-graph-div" style="height:460px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aaac2c8b-c548-4535-bf76-8da030bd51b3")) {                    Plotly.newPlot(                        "aaac2c8b-c548-4535-bf76-8da030bd51b3",                        [{"alignmentgroup":"True","hovertemplate":"ระบบ=School Bus\u003cbr\u003e=%{x}\u003cbr\u003eYoY Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"School Bus","marker":{"color":"#FFB347","pattern":{"shape":""}},"name":"School Bus","offsetgroup":"School Bus","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1f}","x":[2025],"xaxis":"x","y":[-2.332745309566242],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบ=Ferry\u003cbr\u003e=%{x}\u003cbr\u003eYoY Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ferry","marker":{"color":"#FF6B6B","pattern":{"shape":""}},"name":"Ferry","offsetgroup":"Ferry","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1f}","x":[2025],"xaxis":"x","y":[-2.3797335345071446],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบ=Airport Rail\u003cbr\u003e=%{x}\u003cbr\u003eYoY Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Airport Rail","marker":{"color":"#74B9FF","pattern":{"shape":""}},"name":"Airport Rail","offsetgroup":"Airport Rail","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1f}","x":[2025],"xaxis":"x","y":[12.081676607024527],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบ=KRL Commuter\u003cbr\u003e=%{x}\u003cbr\u003eYoY Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"KRL Commuter","marker":{"color":"#4ECDC4","pattern":{"shape":""}},"name":"KRL Commuter","offsetgroup":"KRL Commuter","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1f}","x":[2025],"xaxis":"x","y":[12.79499729922633],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบ=LRT Jakarta\u003cbr\u003e=%{x}\u003cbr\u003eYoY Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LRT Jakarta","marker":{"color":"#C77DFF","pattern":{"shape":""}},"name":"LRT Jakarta","offsetgroup":"LRT Jakarta","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1f}","x":[2025],"xaxis":"x","y":[5.414498459996175],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบ=MRT Jakarta\u003cbr\u003e=%{x}\u003cbr\u003eYoY Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MRT Jakarta","marker":{"color":"#A8E6CF","pattern":{"shape":""}},"name":"MRT Jakarta","offsetgroup":"MRT Jakarta","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1f}","x":[2025],"xaxis":"x","y":[13.372068262251812],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"ระบบ=TransJakarta (BRT)\u003cbr\u003e=%{x}\u003cbr\u003eYoY Change (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TransJakarta (BRT)","marker":{"color":"#FD79A8","pattern":{"shape":""}},"name":"TransJakarta (BRT)","offsetgroup":"TransJakarta (BRT)","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y:.1f}","x":[2025],"xaxis":"x","y":[8.482214451971192],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10 ...
